# %% [markdown]
# <a href="https://colab.research.google.com/github/tl614-rutgers/gisTest/blob/main/ps1_submit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Data Sources:
#
# https://data.cdc.gov/Public-Health-Surveillance/United-States-COVID-19-Community-Levels-by-County/3nnm-4jni/data hospitalization data
#
# https://usafacts.org/visualizations/coronavirus-covid-19-spread-map/state/new-jersey/ covid deaths data
#
# https://www.google.com/url?sa=t&rct=j&q=&esrc=s&source=web&cd=&ved=2ahUKEwi-h9WmqMuBAxXAlWoFHVG7CPIQFnoECBYQAQ&url=https%3A%2F%2Fwww.nj.gov%2Flabor%2Flabormarketinformation%2Fassets%2FPDFs%2Fdmograph%2Fest%2Fmcd%2Fdensity.xlsx&usg=AOvVaw2WUNow4omLDOveDVwJYnAc&opi=89978449 population density data of 2020

# %% [markdown]
# ### My Plan
# I plan on doing my research on covid-19 within NJ counties seeing which area had the most deaths and seeing which counties had the most hospitalizations related to covid and how it relates to the population density. I plan to provide further research in seeing how people were affected by covid relating to racial ethnic groups.

# %%
import os, zipfile
import pandas as pd
import matplotlib.pyplot as plt

import geopandas as gpd
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
from google.colab import files
from google.colab import data_table
data_table.enable_dataframe_formatter()

# %%
# !pip install mapclassify
import mapclassify
# Out:
# Collecting mapclassify
#   Downloading mapclassify-2.6.0-py3-none-any.whl (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.8/40.8 kB 1.3 MB/s eta 0:00:00
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.10/dist-packages (from mapclassify) (1.11.2)
# Requirement already satisfied: numpy>=1.3 in /usr/local/lib/python3.10/dist-packages (from mapclassify) (1.23.5)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from mapclassify) (1.2.2)
# Requirement already satisfied: pandas>=1.0 in /usr/local/lib/python3.10/dist-packages (from mapclassify) (1.5.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from mapclassify) (3.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0->mapclassify) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0->mapclassify) (2023.3.post1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->mapclassify) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->mapclassify) (3.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=1.0->mapclassify) (1.16.0)
# Installing collected packages: mapclassify
# Successfully installed mapclassify-2.6.0

# %%
! wget -q -O bounds_nj_shp.zip https://docs.google.com/uc?id=1GUI-JMkom1XFGaa0k77C1JmlEVH6Eenu&export=download
zip_ref = zipfile.ZipFile('bounds_nj_shp.zip', 'r'); zip_ref.extractall(); zip_ref.close()
njc=gpd.read_file('nj_counties.shp')

# %%
njc.plot()
# Out:
# <Axes: >

# %%
njc.dtypes
# Out:
# COUNTY          object
# COUNTY_LAB      object
# CO              object
# GNIS_NAME       object
# GNIS            object
# FIPSSTCO        object
# FIPSCO          object
# ACRES          float64
# SQ_MILES       float64
# POP2010          int64
# POP2000          int64
# POP1990          int64
# POP1980          int64
# POPDEN2010       int64
# POPDEN2000       int64
# POPDEN1990       int64
# POPDEN1980       int64
# REGION          object
# Shape_Leng     float64
# Shape_Area     float64
# geometry      geometry
# dtype: object

# %%
njc.head(5)
# Out:
# Warning: Total number of columns (21) exceeds max_columns (20). Falling back to pandas display.
#        COUNTY         COUNTY_LAB   CO             GNIS_NAME    GNIS FIPSSTCO  \
# 0    ATLANTIC    Atlantic County  ATL    County of Atlantic  882270    34001
# 1      BERGEN      Bergen County  BER      County of Bergen  882271    34003
# 2  BURLINGTON  Burlington County  BUR  County of Burlington  882272    34005
# 3      CAMDEN      Camden County  CAM      County of Camden  882273    34007
# 4    CAPE MAY    Cape May County  CAP    County of Cape May  882274    34009
#
#   FIPSCO          ACRES    SQ_MILES  POP2010  ...  POP1990  POP1980  \
# 0      1  390815.404215  610.649069   274549  ...   275372   204615
# 1      3  153490.275182  239.828555   905116  ...   829592   849843
# 2      5  525002.683590  820.316693   448734  ...   395066   362542
# 3      7  145650.507808  227.578918   513657  ...   532498   471650
# 4      9  183126.574240  286.135272    97265  ...    95089    82266
#
#    POPDEN2010  POPDEN2000  POPDEN1990  POPDEN1980        REGION  \
# 0         450         414         451         335       COASTAL
# 1        3774        3686        3459        3544  NORTHEASTERN
# 2         547         516         482         442      SOUTHERN
# 3        2257        2236        2340        2073      SOUTHERN
# 4         340         358         332         288       COASTAL
#
#       Shape_Leng    Shape_Area  \
# 0  650228.153906  1.702385e+10
# 1  443326.122021  6.686010e+09
# 2  788906.717476  2.286903e+10
# 3  495010.034901  6.344511e+09
# 4  514564.858771  7.976962e+09
#
#                                             geometry
# 0  POLYGON ((443056.010 311529.770, 443068.440 31...
# 1  POLYGON ((656200.963 783614.366, 656141.127 78...
# 2  POLYGON ((436626.690 491361.780, 436701.190 49...
# 3  POLYGON ((342763.990 423475.830, 342804.100 42...
# 4  POLYGON ((390389.730 177065.130, 390410.170 17...
#
# [5 rows x 21 columns]

# %%
! wget -q -O density.csv https://raw.githubusercontent.com/tl614-rutgers/gisTest/main/density.csv
popden = pd.read_csv('density.csv')
popden
# Out:
#    Population and Population Density by County: New Jersey, Census 2020 and Estimates 2022  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                FIPS
# 4                                               34000
# 5                                                 NaN
# 6                                               34001
# 7                                               34003
# 8                                               34005
# 9                                               34007
# 10                                              34009
# 11                                              34011
# 12                                              34013
# 13                                              34015
# 14                                              34017
# 15                                              34019
# 16                                              34021
# 17                                              34023
# 18                                              34025
# 19                                              34027
# 20                                              34029
# 21                                              34031
# 22                                              34033
# 23                                              34035
# 24                                              34037
# 25                                              34039
# 26                                              34041
# 27                                                NaN
# 28  Note: Population density was calculated based ...
# 29            different from land area data indica...
# 30                                                NaN
# 31  Source: U.S. Census Bureau, Population Divisio...
# 32                             Release Date: May 2023
#
#            Unnamed: 1  Unnamed: 2  Unnamed: 3           Unnamed: 4 Unnamed: 5  \
# 0                 NaN         NaN         NaN                  NaN        NaN
# 1                 NaN   Land Area         NaN  Resident Population        NaN
# 2                 NaN  in Square          NaN               Census  Estimates
# 3              County      Miles          NaN                 2020       2022
# 4          New Jersey     7,354.8         NaN            9,289,031  9,261,699
# 5                 NaN         NaN         NaN                  NaN        NaN
# 6     Atlantic County       555.5         NaN              274,536    275,638
# 7       Bergen County       232.8         NaN              955,746    952,997
# 8   Burlington County       799.3         NaN              461,863    466,103
# 9       Camden County       221.4         NaN              523,486    524,907
# 10    Cape May County       251.5         NaN               95,266     95,634
# 11  Cumberland County       483.4         NaN              154,148    151,356
# 12       Essex County       126.1         NaN              862,782    849,477
# 13  Gloucester County       322.0         NaN              302,285    306,601
# 14      Hudson County        46.2         NaN              724,857    703,366
# 15   Hunterdon County       427.8         NaN              128,962    129,777
# 16      Mercer County       224.4         NaN              387,340    380,688
# 17   Middlesex County       309.2         NaN              863,183    861,418
# 18    Monmouth County       468.2         NaN              643,608    644,098
# 19      Morris County       461.0         NaN              509,277    511,151
# 20       Ocean County       628.3         NaN              637,229    655,735
# 21     Passaic County       186.0         NaN              525,052    513,936
# 22       Salem County       331.9         NaN               64,834     65,117
# 23    Somerset County       301.9         NaN              345,356    346,875
# 24      Sussex County       518.7         NaN              144,231    146,084
# 25       Union County       102.8         NaN              575,352    569,815
# 26      Warren County       356.5         NaN              109,638    110,926
# 27                NaN         NaN         NaN                  NaN        NaN
# 28                NaN         NaN         NaN                  NaN        NaN
# 29                NaN         NaN         NaN                  NaN        NaN
# 30                NaN         NaN         NaN                  NaN        NaN
# 31                NaN         NaN         NaN                  NaN        NaN
# 32                NaN         NaN         NaN                  NaN        NaN
#
#     Unnamed: 6                  Unnamed: 7  Unnamed: 8
# 0          NaN                         NaN         NaN
# 1          NaN  Population per square mile         NaN
# 2          NaN                     Census    Estimates
# 3          NaN                        2020        2022
# 4          NaN                    1,263.0     1,259.3
# 5          NaN                         NaN         NaN
# 6          NaN                      494.2       496.2
# 7          NaN                    4,105.6     4,093.8
# 8          NaN                      577.8       583.1
# 9          NaN                    2,364.9     2,371.3
# 10         NaN                      378.8       380.2
# 11         NaN                      318.9       313.1
# 12         NaN                    6,842.9     6,737.4
# 13         NaN                      938.8       952.2
# 14         NaN                   15,691.7    15,226.5
# 15         NaN                      301.4       303.3
# 16         NaN                    1,725.8     1,696.2
# 17         NaN                    2,791.5     2,785.8
# 18         NaN                    1,374.7     1,375.7
# 19         NaN                    1,104.8     1,108.9
# 20         NaN                    1,014.2     1,043.7
# 21         NaN                    2,822.7     2,762.9
# 22         NaN                      195.4       196.2
# 23         NaN                    1,144.1     1,149.1
# 24         NaN                      278.1       281.7
# 25         NaN                    5,598.6     5,544.8
# 26         NaN                      307.5       311.1
# 27         NaN                         NaN         NaN
# 28         NaN                         NaN         NaN
# 29         NaN                         NaN         NaN
# 30         NaN                         NaN         NaN
# 31         NaN                         NaN         NaN
# 32         NaN                         NaN         NaN

# %%
popden.dtypes
# Out:
# Population and Population Density by County: New Jersey, Census 2020 and Estimates 2022     object
# Unnamed: 1                                                                                  object
# Unnamed: 2                                                                                  object
# Unnamed: 3                                                                                 float64
# Unnamed: 4                                                                                  object
# Unnamed: 5                                                                                  object
# Unnamed: 6                                                                                 float64
# Unnamed: 7                                                                                  object
# Unnamed: 8                                                                                  object
# dtype: object

# %%
popden1 = popden[['Unnamed: 1', 'Unnamed: 7']]
popden1.rename(columns={'Unnamed: 1': 'county'}, inplace=True)
popden1.rename(columns={'Unnamed: 7': 'popden2020'}, inplace=True)
popden1
# Out:
# <ipython-input-9-a64ce4afe56b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   popden1.rename(columns={'Unnamed: 1': 'county'}, inplace=True)
# <ipython-input-9-a64ce4afe56b>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   popden1.rename(columns={'Unnamed: 7': 'popden2020'}, inplace=True)
#                county                  popden2020
# 0                 NaN                         NaN
# 1                 NaN  Population per square mile
# 2                 NaN                     Census
# 3              County                        2020
# 4          New Jersey                    1,263.0
# 5                 NaN                         NaN
# 6     Atlantic County                      494.2
# 7       Bergen County                    4,105.6
# 8   Burlington County                      577.8
# 9       Camden County                    2,364.9
# 10    Cape May County                      378.8
# 11  Cumberland County                      318.9
# 12       Essex County                    6,842.9
# 13  Gloucester County                      938.8
# 14      Hudson County                   15,691.7
# 15   Hunterdon County                      301.4
# 16      Mercer County                    1,725.8
# 17   Middlesex County                    2,791.5
# 18    Monmouth County                    1,374.7
# 19      Morris County                    1,104.8
# 20       Ocean County                    1,014.2
# 21     Passaic County                    2,822.7
# 22       Salem County                      195.4
# 23    Somerset County                    1,144.1
# 24      Sussex County                      278.1
# 25       Union County                    5,598.6
# 26      Warren County                      307.5
# 27                NaN                         NaN
# 28                NaN                         NaN
# 29                NaN                         NaN
# 30                NaN                         NaN
# 31                NaN                         NaN
# 32                NaN                         NaN

# %%
popden2 = popden1.iloc[6:27, :]
popden2
# Out:
#                county  popden2020
# 6     Atlantic County      494.2
# 7       Bergen County    4,105.6
# 8   Burlington County      577.8
# 9       Camden County    2,364.9
# 10    Cape May County      378.8
# 11  Cumberland County      318.9
# 12       Essex County    6,842.9
# 13  Gloucester County      938.8
# 14      Hudson County   15,691.7
# 15   Hunterdon County      301.4
# 16      Mercer County    1,725.8
# 17   Middlesex County    2,791.5
# 18    Monmouth County    1,374.7
# 19      Morris County    1,104.8
# 20       Ocean County    1,014.2
# 21     Passaic County    2,822.7
# 22       Salem County      195.4
# 23    Somerset County    1,144.1
# 24      Sussex County      278.1
# 25       Union County    5,598.6
# 26      Warren County      307.5

# %%
njcpopden = pd.merge(njc, popden2, left_on='COUNTY_LAB', right_on='county',how='outer', indicator=True)
njcpopden[['COUNTY_LAB', 'popden2020', '_merge']]
njcpopden1 = pd.merge(njc, popden2, left_on='COUNTY_LAB', right_on='county',how='inner', indicator=False)
# Out:
#            COUNTY_LAB  popden2020 _merge
# 0     Atlantic County      494.2    both
# 1       Bergen County    4,105.6    both
# 2   Burlington County      577.8    both
# 3       Camden County    2,364.9    both
# 4     Cape May County      378.8    both
# 5   Cumberland County      318.9    both
# 6        Essex County    6,842.9    both
# 7   Gloucester County      938.8    both
# 8       Hudson County   15,691.7    both
# 9    Hunterdon County      301.4    both
# 10      Mercer County    1,725.8    both
# 11    Monmouth County    1,374.7    both
# 12       Ocean County    1,014.2    both
# 13     Passaic County    2,822.7    both
# 14       Salem County      195.4    both
# 15    Somerset County    1,144.1    both
# 16      Sussex County      278.1    both
# 17       Union County    5,598.6    both
# 18      Warren County      307.5    both
# 19      Morris County    1,104.8    both
# 20   Middlesex County    2,791.5    both

# %%
fig, ax = plt.subplots(1, figsize=(6,10))
njcpopden.plot(ax=ax,column='popden2020',legend=True,cmap='RdYlGn_r',
          legend_kwds= {"fmt": "{:,.0f}",'loc':'lower right','markerscale':1.4})
ax.title.set_text("Population Density 2020 (pers/sq mi)")
ax.set_xticks([])
ax.set_yticks([])
ax.set_xlabel('''source/definition: https://www.google.com/url?sa=t&rct=j&q=&esrc=s&source=web&cd=&ved=2ahUKEwi-h9WmqMuBAxXAlWoFHVG7CPIQFnoECBYQAQ&url=https%3A%2F%2Fwww.nj.gov%2Flabor%2Flabormarketinformation%2Fassets%2FPDFs%2Fdmograph%2Fest%2Fmcd%2Fdensity.xlsx&usg=AOvVaw2WUNow4omLDOveDVwJYnAc&opi=89978449''')
# Out:
# <Axes: >
# []
# []
# Text(0.5, 80.7222222222222, 'source/definition: https://www.google.com/url?sa=t&rct=j&q=&esrc=s&source=web&cd=&ved=2ahUKEwi-h9WmqMuBAxXAlWoFHVG7CPIQFnoECBYQAQ&url=https%3A%2F%2Fwww.nj.gov%2Flabor%2Flabormarketinformation%2Fassets%2FPDFs%2Fdmograph%2Fest%2Fmcd%2Fdensity.xlsx&usg=AOvVaw2WUNow4omLDOveDVwJYnAc&opi=89978449')

# %%
! wget -q -O covid_deaths_usafacts.csv https://raw.githubusercontent.com/tl614-rutgers/gisTest/main/covid_deaths_usafacts.csv
nj_deaths = pd.read_csv('covid_deaths_usafacts.csv')
selected_rows = nj_deaths.loc[nj_deaths['State'] == 'NJ']
selected_rows.head(5)
# Out:
# Warning: Total number of columns (1269) exceeds max_columns (20). Falling back to pandas display.
#       countyFIPS            County Name State  StateFIPS  2020-01-22  \
# 1804           0  Statewide Unallocated    NJ         34           0
# 1805       34001       Atlantic County     NJ         34           0
# 1806       34003         Bergen County     NJ         34           0
# 1807       34005     Burlington County     NJ         34           0
# 1808       34007         Camden County     NJ         34           0
#
#       2020-01-23  2020-01-24  2020-01-25  2020-01-26  2020-01-27  ...  \
# 1804           0           0           0           0           0  ...
# 1805           0           0           0           0           0  ...
# 1806           0           0           0           0           0  ...
# 1807           0           0           0           0           0  ...
# 1808           0           0           0           0           0  ...
#
#       2023-07-14  2023-07-15  2023-07-16  2023-07-17  2023-07-18  2023-07-19  \
# 1804           0           0           0           0           0           0
# 1805        1073        1073        1073        1073        1073        1073
# 1806        3708        3708        3708        3708        3708        3708
# 1807        1364        1364        1364        1364        1364        1364
# 1808        1959        1959        1959        1959        1959        1959
#
#       2023-07-20  2023-07-21  2023-07-22  2023-07-23
# 1804           0           0           0           0
# 1805        1073        1073        1073        1073
# 1806        3708        3708        3708        3708
# 1807        1364        1364        1364        1364
# 1808        1959        1959        1959        1959
#
# [5 rows x 1269 columns]

# %%
selected_rows.dtypes
# Out:
# countyFIPS      int64
# County Name    object
# State          object
# StateFIPS       int64
# 2020-01-22      int64
#                 ...
# 2023-07-19      int64
# 2023-07-20      int64
# 2023-07-21      int64
# 2023-07-22      int64
# 2023-07-23      int64
# Length: 1269, dtype: object

# %%
selected_rows1 = selected_rows[['County Name', '2021-08-11']]
selected_rows1.rename(columns={'County Name': 'county'}, inplace=True)
selected_rows1.rename(columns={'2021-08-11': 'aug 11, 2021'}, inplace=True)
selected_rows1
# Out:
# <ipython-input-15-dd53c04e59d0>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_rows1.rename(columns={'County Name': 'county'}, inplace=True)
# <ipython-input-15-dd53c04e59d0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_rows1.rename(columns={'2021-08-11': 'aug 11, 2021'}, inplace=True)
#                      county  aug 11, 2021
# 1804  Statewide Unallocated            17
# 1805       Atlantic County            698
# 1806         Bergen County           2905
# 1807     Burlington County            886
# 1808         Camden County           1346
# 1809       Cape May County            209
# 1810     Cumberland County            441
# 1811          Essex County           3041
# 1812     Gloucester County            648
# 1813         Hudson County           2316
# 1814      Hunterdon County            177
# 1815         Mercer County            965
# 1816      Middlesex County           2376
# 1817       Monmouth County           1647
# 1818         Morris County           1245
# 1819          Ocean County           2182
# 1820        Passaic County           1948
# 1821          Salem County            172
# 1822       Somerset County            846
# 1823         Sussex County            309
# 1824          Union County           1991
# 1825         Warren County            241

# %%
selected_rows2 = selected_rows1.iloc[1:, :]
selected_rows2
# Out:
#                   county  aug 11, 2021
# 1805    Atlantic County            698
# 1806      Bergen County           2905
# 1807  Burlington County            886
# 1808      Camden County           1346
# 1809    Cape May County            209
# 1810  Cumberland County            441
# 1811       Essex County           3041
# 1812  Gloucester County            648
# 1813      Hudson County           2316
# 1814   Hunterdon County            177
# 1815      Mercer County            965
# 1816   Middlesex County           2376
# 1817    Monmouth County           1647
# 1818      Morris County           1245
# 1819       Ocean County           2182
# 1820     Passaic County           1948
# 1821       Salem County            172
# 1822    Somerset County            846
# 1823      Sussex County            309
# 1824       Union County           1991
# 1825      Warren County            241

# %%
selected_rows2['COUNTY'] = selected_rows2['county'].str.upper()
njd = selected_rows2
njd
# Out:
# <ipython-input-17-2fe418dddcd7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_rows2['COUNTY'] = selected_rows2['county'].str.upper()
#                   county  aug 11, 2021              COUNTY
# 1805    Atlantic County            698    ATLANTIC COUNTY
# 1806      Bergen County           2905      BERGEN COUNTY
# 1807  Burlington County            886  BURLINGTON COUNTY
# 1808      Camden County           1346      CAMDEN COUNTY
# 1809    Cape May County            209    CAPE MAY COUNTY
# 1810  Cumberland County            441  CUMBERLAND COUNTY
# 1811       Essex County           3041       ESSEX COUNTY
# 1812  Gloucester County            648  GLOUCESTER COUNTY
# 1813      Hudson County           2316      HUDSON COUNTY
# 1814   Hunterdon County            177   HUNTERDON COUNTY
# 1815      Mercer County            965      MERCER COUNTY
# 1816   Middlesex County           2376   MIDDLESEX COUNTY
# 1817    Monmouth County           1647    MONMOUTH COUNTY
# 1818      Morris County           1245      MORRIS COUNTY
# 1819       Ocean County           2182       OCEAN COUNTY
# 1820     Passaic County           1948     PASSAIC COUNTY
# 1821       Salem County            172       SALEM COUNTY
# 1822    Somerset County            846    SOMERSET COUNTY
# 1823      Sussex County            309      SUSSEX COUNTY
# 1824       Union County           1991       UNION COUNTY
# 1825      Warren County            241      WARREN COUNTY

# %%
njd['c']=njd.county.str.replace('County ','County')
# Out:
# <ipython-input-18-31405b534cb1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   njd['c']=njd.county.str.replace('County ','County')

# %%
njc1 = pd.merge(njc, njd, left_on='COUNTY_LAB', right_on='c', how='outer', indicator=True)
njc1[['COUNTY_LAB', 'aug 11, 2021', '_merge']]
njc2 = pd.merge(njc, njd, left_on='COUNTY_LAB', right_on='c', how='outer', indicator=False)
# Out:
#            COUNTY_LAB  aug 11, 2021 _merge
# 0     Atlantic County           698   both
# 1       Bergen County          2905   both
# 2   Burlington County           886   both
# 3       Camden County          1346   both
# 4     Cape May County           209   both
# 5   Cumberland County           441   both
# 6        Essex County          3041   both
# 7   Gloucester County           648   both
# 8       Hudson County          2316   both
# 9    Hunterdon County           177   both
# 10      Mercer County           965   both
# 11    Monmouth County          1647   both
# 12       Ocean County          2182   both
# 13     Passaic County          1948   both
# 14       Salem County           172   both
# 15    Somerset County           846   both
# 16      Sussex County           309   both
# 17       Union County          1991   both
# 18      Warren County           241   both
# 19      Morris County          1245   both
# 20   Middlesex County          2376   both

# %%
fig, ax = plt.subplots(1, figsize=(6,10))
njc2.plot(ax=ax,column='aug 11, 2021',legend=True,cmap='RdYlGn_r',
          scheme='natural_breaks',k=5, edgecolor='grey',linewidth=2,
          legend_kwds= {"fmt": "{:,.0f}",'loc':'lower right','markerscale':1.4})
ax.title.set_text("Covid Deaths in NJ Counties")
ax.set_xticks([])
ax.set_yticks([])
ax.set_xlabel('''source/definition: https://usafacts.org/visualizations/coronavirus-covid-19-spread-map/state/new-jersey/''')
# Out:
# <Axes: >
# []
# []
# Text(0.5, 80.7222222222222, 'source/definition: https://usafacts.org/visualizations/coronavirus-covid-19-spread-map/state/new-jersey/')

# %%
# !wget -q -O United_States_COVID-19_Community_Levels_by_County.csv https://raw.githubusercontent.com/tl614-rutgers/gisTest/main/United_States_COVID-19_Community_Levels_by_County.csv
hosp_admit = pd.read_csv('United_States_COVID-19_Community_Levels_by_County.csv')
rows_selected = hosp_admit.loc[hosp_admit['date_updated'] == '8/11/22']
rows_selected.head(5)
# Out:
#         county  county_fips       state  county_population  \
# 16   Cape May         34009  New Jersey              92039
# 17  Hunterdon         34019  New Jersey             124371
# 18   Monmouth         34025  New Jersey             618795
# 19      Salem         34033  New Jersey              62385
# 20     Warren         34041  New Jersey             105267
#
#     health_service_area_number                          health_service_area  \
# 16                          64  Atlantic (Atlantic City), NJ - Cape May, NJ
# 17                          93    Hunterdon, NJ - Warren (Phillipsburg), NJ
# 18                         108    Monmouth, NJ - Ocean (Brick Township), NJ
# 19                          23         Camden (Camden), NJ - Burlington, NJ
# 20                          93    Hunterdon, NJ - Warren (Phillipsburg), NJ
#
#     health_service_area_population  covid_inpatient_bed_utilization  \
# 16                          355709                              5.0
# 17                          229638                              3.3
# 18                         1225981                              6.5
# 19                         1305841                              6.0
# 20                          229638                              3.3
#
#     covid_hospital_admissions_per_100k  covid_cases_per_100k  \
# 16                                27.3                272.71
# 17                                10.0                176.09
# 18                                16.5                234.00
# 19                                17.5                203.57
# 20                                10.0                164.34
#
#    covid-19_community_level date_updated
# 16                     High      8/11/22
# 17                   Medium      8/11/22
# 18                     High      8/11/22
# 19                     High      8/11/22
# 20                   Medium      8/11/22

# %%
rows_selected.dtypes
# Out:
# county                                 object
# county_fips                             int64
# state                                  object
# county_population                       int64
# health_service_area_number              int64
# health_service_area                    object
# health_service_area_population          int64
# covid_inpatient_bed_utilization       float64
# covid_hospital_admissions_per_100k    float64
# covid_cases_per_100k                  float64
# covid-19_community_level               object
# date_updated                           object
# dtype: object

# %%
rows_selected1 = rows_selected[['county', 'covid_hospital_admissions_per_100k', 'date_updated']]
rows_selected1.rename(columns={'covid_hospital_admissions_per_100k': 'covid_hosp_admissions/100k'}, inplace=True)
rows_selected1
# Out:
# <ipython-input-23-0b1f5705f567>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rows_selected1.rename(columns={'covid_hospital_admissions_per_100k': 'covid_hosp_admissions/100k'}, inplace=True)
#          county  covid_hosp_admissions/100k date_updated
# 16    Cape May                         27.3      8/11/22
# 17   Hunterdon                         10.0      8/11/22
# 18    Monmouth                         16.5      8/11/22
# 19       Salem                         17.5      8/11/22
# 20      Warren                         10.0      8/11/22
# 21  Cumberland                          0.0      8/11/22
# 22       Essex                         11.4      8/11/22
# 23      Mercer                         10.3      8/11/22
# 24   Middlesex                         11.4      8/11/22
# 25     Passaic                         11.3      8/11/22
# 26      Sussex                         13.9      8/11/22
# 27       Union                         11.4      8/11/22
# 28    Atlantic                         27.3      8/11/22
# 29      Bergen                         11.3      8/11/22
# 30  Gloucester                         17.5      8/11/22
# 31      Hudson                         11.3      8/11/22
# 32      Morris                         13.9      8/11/22
# 33  Burlington                         17.5      8/11/22
# 34      Camden                         17.5      8/11/22
# 35       Ocean                         16.5      8/11/22
# 36    Somerset                         11.4      8/11/22

# %%
rows_selected2=rows_selected1.iloc[0:, :]
rows_selected2
# Out:
#          county  covid_hosp_admissions/100k date_updated
# 16    Cape May                         27.3      8/11/22
# 17   Hunterdon                         10.0      8/11/22
# 18    Monmouth                         16.5      8/11/22
# 19       Salem                         17.5      8/11/22
# 20      Warren                         10.0      8/11/22
# 21  Cumberland                          0.0      8/11/22
# 22       Essex                         11.4      8/11/22
# 23      Mercer                         10.3      8/11/22
# 24   Middlesex                         11.4      8/11/22
# 25     Passaic                         11.3      8/11/22
# 26      Sussex                         13.9      8/11/22
# 27       Union                         11.4      8/11/22
# 28    Atlantic                         27.3      8/11/22
# 29      Bergen                         11.3      8/11/22
# 30  Gloucester                         17.5      8/11/22
# 31      Hudson                         11.3      8/11/22
# 32      Morris                         13.9      8/11/22
# 33  Burlington                         17.5      8/11/22
# 34      Camden                         17.5      8/11/22
# 35       Ocean                         16.5      8/11/22
# 36    Somerset                         11.4      8/11/22

# %%
rows_selected2['COUNTY'] = rows_selected2['county'].str.upper().str.strip()
ha = rows_selected2
ha
# Out:
# <ipython-input-25-a1996ac3ff24>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rows_selected2['COUNTY'] = rows_selected2['county'].str.upper().str.strip()
#          county  covid_hosp_admissions/100k date_updated      COUNTY
# 16    Cape May                         27.3      8/11/22    CAPE MAY
# 17   Hunterdon                         10.0      8/11/22   HUNTERDON
# 18    Monmouth                         16.5      8/11/22    MONMOUTH
# 19       Salem                         17.5      8/11/22       SALEM
# 20      Warren                         10.0      8/11/22      WARREN
# 21  Cumberland                          0.0      8/11/22  CUMBERLAND
# 22       Essex                         11.4      8/11/22       ESSEX
# 23      Mercer                         10.3      8/11/22      MERCER
# 24   Middlesex                         11.4      8/11/22   MIDDLESEX
# 25     Passaic                         11.3      8/11/22     PASSAIC
# 26      Sussex                         13.9      8/11/22      SUSSEX
# 27       Union                         11.4      8/11/22       UNION
# 28    Atlantic                         27.3      8/11/22    ATLANTIC
# 29      Bergen                         11.3      8/11/22      BERGEN
# 30  Gloucester                         17.5      8/11/22  GLOUCESTER
# 31      Hudson                         11.3      8/11/22      HUDSON
# 32      Morris                         13.9      8/11/22      MORRIS
# 33  Burlington                         17.5      8/11/22  BURLINGTON
# 34      Camden                         17.5      8/11/22      CAMDEN
# 35       Ocean                         16.5      8/11/22       OCEAN
# 36    Somerset                         11.4      8/11/22    SOMERSET

# %%
njc3 = pd.merge(njc, ha, on='COUNTY', how='outer', indicator=True)
njc3[['COUNTY', 'covid_hosp_admissions/100k', 'date_updated', '_merge']]
njc4 = pd.merge(njc, ha, on='COUNTY', how='outer', indicator=False)
# Out:
#         COUNTY  covid_hosp_admissions/100k date_updated _merge
# 0     ATLANTIC                        27.3      8/11/22   both
# 1       BERGEN                        11.3      8/11/22   both
# 2   BURLINGTON                        17.5      8/11/22   both
# 3       CAMDEN                        17.5      8/11/22   both
# 4     CAPE MAY                        27.3      8/11/22   both
# 5   CUMBERLAND                         0.0      8/11/22   both
# 6        ESSEX                        11.4      8/11/22   both
# 7   GLOUCESTER                        17.5      8/11/22   both
# 8       HUDSON                        11.3      8/11/22   both
# 9    HUNTERDON                        10.0      8/11/22   both
# 10      MERCER                        10.3      8/11/22   both
# 11    MONMOUTH                        16.5      8/11/22   both
# 12       OCEAN                        16.5      8/11/22   both
# 13     PASSAIC                        11.3      8/11/22   both
# 14       SALEM                        17.5      8/11/22   both
# 15    SOMERSET                        11.4      8/11/22   both
# 16      SUSSEX                        13.9      8/11/22   both
# 17       UNION                        11.4      8/11/22   both
# 18      WARREN                        10.0      8/11/22   both
# 19      MORRIS                        13.9      8/11/22   both
# 20   MIDDLESEX                        11.4      8/11/22   both

# %%
fig, ax = plt.subplots(1, figsize=(6,10))
njc3.plot(ax=ax,column='covid_hosp_admissions/100k',legend=True,cmap='RdYlGn_r',
          scheme='natural_breaks',k=5, edgecolor='grey',linewidth=2,
          legend_kwds= {"fmt": "{:,.0f}",'loc':'lower right','markerscale':1.4})
ax.title.set_text("Covid Hospital Admissions")
ax.set_xticks([])
ax.set_yticks([])
ax.set_xlabel('''source/definition: https://data.cdc.gov/Public-Health-Surveillance/United-States-COVID-19-Community-Levels-by-County/3nnm-4jni/data''')
# Out:
# <Axes: >
# []
# []
# Text(0.5, 80.7222222222222, 'source/definition: https://data.cdc.gov/Public-Health-Surveillance/United-States-COVID-19-Community-Levels-by-County/3nnm-4jni/data')
